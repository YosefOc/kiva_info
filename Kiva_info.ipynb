# %%
# This is part of the Kiva project analysis of data. The website readily provides json and xml files. 
# The source of the data is http://build.kiva.org/docs/data/snapshots and it comes in json and xml format
#

# %%
# first step- use code to import pandas as PD
import pandas as pd

# %%
# Second step: Import json. 
#The command that follows is a pandas utility function called json_normalize that flattens semi-structured JSON objects. 
import json 
from pandas.io.json import json_normalize

# %%
# Load a json file from Kiva database 
json.load((open('data/556.json')))
# Out:
# {'header': {'date': '2017-04-03T17:58:16Z',
#   'page': 556,
#   'page_size': 1000,
#   'total': 1138210},
#  'loans_lenders': [{'id': 573547,
#    'lender_ids': ['billijo4372',
#     'jmehta4kiva',
#     'lucas8959',
#     'kimberly7838',
#     'mary4126',
#     'laura8990',
#     'fran9286',
#     'scot2162',
#     'ann5687',
#     'thomas3791',
#     'cathy69432806',
#     'judie9032',
#     'sophie4280',
#     'patrick2650',
#     'giovanni9923',
#     'interlocfilms',
#     'adam6608',
#     'sofia4942',
#     'angus2640',
#     'sota4018',
#     'terry9277',
#     'rossdeb7004',
#     'keiko',
#     'nina3473',
#     'alkesh',
#     'thiagolg',
#     'brigitta2619',
#     'lisa5754',
#     'niall1106',
#     'maria4534',
#     'thierry8170',
#     'kim7063',
#     'wongacom3393',
#     'kaitlyn9174']},
#   {'id': 573548,
#    'lender_ids': ['edward7173',
#     'trolltech4460',
#     'patrick40953074',
#     'peteranna4092',
#     'ron2622',
#     'funkymonkey4439',
# ...

# %%
# Load as pandas data frame 

KivaDF= pd.read_json((open('data/556.json')))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a7e089bc632e> in <module>()
#       1 # Load as pandas data frame
#       2
# ----> 3 KivaDF= pd.read_json((open('data/556.json')))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines)
#     279         obj = FrameParser(json, orient, dtype, convert_axes, convert_dates,
#     280                           keep_default_dates, numpy, precise_float,
# --> 281                           date_unit).parse()
#     282
#     283     if typ == 'series' or obj is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json.py in parse(self)
#     347
#     348         else:
# --> 349             self._parse_no_numpy()
#     350
# ...
